# %%
#Dependencies

import pandas as pd
import numpy
import os

# %%
#Open data file and create dataframe

#curdir = os.getcwd()
#print(curdir)

path = "Resources/purchase_data.csv"
HOP_df = pd.read_csv(path, encoding="ISO-8859-1")

HOP_df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
#Clean up the data if needed

HOP_df.count()
HOP_df.dtypes

#o_HOP_df = HOP_df.rename(columns={'SN':'Screen Name'})

o_HOP_df['Gender'].value_counts()

o_HOP_df = o_HOP_df.dropna(how='any')

# %%
#Player Count
#
#Total Number of Players

Total_Players = o_HOP_df['Screen Name'].nunique()
Total_Players
# Out:
# 576

# %%
#Purchasing Analysis (Total)
#
#Number of Unique Items
#Average Purchase Price
#Total Number of Purchases
#Total Revenue


Unique_Items = o_HOP_df['Item ID'].nunique()
Unique_Items

Total_PP = round(o_HOP_df['Price'].sum(),2)
Count_PP = o_HOP_df['Price'].count()
Avg_PP = round(Total_PP/Count_PP,2)
Avg_PP
# Out:
# 3.05

# %%
#Summary report for the Purchasing Analysis


Purchasing_summary_df = pd.DataFrame({
    'No. of Unique Items': [Unique_Items],
    'Avg Purchase Price': [Avg_PP],
    'Total No. of Purchases': [Count_PP],
    'Total Revenue': [Total_PP]


})

Purchasing_summary_df
# Out:
#    No. of Unique Items  Avg Purchase Price  Total No. of Purchases  \
# 0                  183                3.05                     780
#
#    Total Revenue
# 0        2379.77

# %%
#Gender Demographics
#
#Percentage and Count of Male Players
#Percentage and Count of Female Players
#Percentage and Count of Other / Non-Disclosed



Male_df = o_HOP_df.loc[o_HOP_df['Gender'] == 'Male']
Count_Male = Male_df['Screen Name'].nunique()
Count_Male

Female_df = o_HOP_df.loc[o_HOP_df['Gender']=='Female']
Count_Female = Female_df['Screen Name'].nunique()
Count_Female

Other_df = o_HOP_df.loc[o_HOP_df['Gender']=='Other / Non-Disclosed']
Count_Other = Other_df['Screen Name'].nunique()
Count_Other

Male_Pct = round(Count_Male/Total_Players *100,2)
Male_Pct

Female_Pct = round(Count_Female/Total_Players *100,2)
Female_Pct

Other_Pct = round(Count_Other/Total_Players *100,2)
Other_Pct
# Out:
# 1.91

# %%
#Summary report for Gender Demographics


Gender_summary_df = pd.DataFrame({
    'Male Players': [Count_Male],
    '% of Male Players': str(Male_Pct) + '%',
    'Female Players': [Count_Female],
    '% of Female Players': str(Female_Pct) + '%',
    'Other/Not Disclosed': [Count_Other],
    '% of Other/Not Disclosed': str(Other_Pct) + '%'


})


Gender_summary_df = Gender_summary_df.stack()
Gender_summary_df
# Out:
# 0  Male Players                   484
#    % of Male Players           84.03%
#    Female Players                  81
#    % of Female Players         14.06%
#    Other/Not Disclosed             11
#    % of Other/Not Disclosed     1.91%
# dtype: object

# %%
raw_data = {

 'Player Count':[Count_Male, Count_Female, Count_Other],
 'Player Percentage':[Male_Pct, Female_Pct, Other_Pct]
      
}

newdf = pd.DataFrame(raw_data)
newdf
# Out:
#    Player Count  Player Percentage
# 0           484              84.03
# 1            81              14.06
# 2            11               1.91

# %%
#Purchasing Analysis (Gender)
#
#The below each broken by gender
#
#Purchase Count
#Average Purchase Price
#Total Purchase Value
#Average Purchase Total per Person by Gender
# Out:
# 652

# %%
#Summary report for Purchasing Analysis (Gender)

# %%
o_HOP_df[o_HOP_df.Gender == 'Male']
# Out:
#   File "<ipython-input-124-07f2cf93d2a0>", line 1
#     o_HOP_df[o_HOP_df.Gender == 'Male'] & [o_HOP_df.Gender =='Female')]
#                                                                      ^
# SyntaxError: invalid syntax

# %%
gendf = o_HOP_df.groupby('Gender').count()
gendf


aggtest = o_HOP_df.groupby(['Gender','Item Name']).agg({'Gender':['count']})
aggtest
# Out:
#                                                                 Gender
#                                                                  count
# Gender                Item Name
# Female                Aetherius, Boon of the Blessed                 1
#                       Alpha                                          1
#                       Alpha, Oath of Zeal                            1
#                       Arcane Gem                                     1
#                       Betrayal, Whisper of Grieving Widows           1
#                       Blood Infused Guardian                         1
#                       Brimstone                                      1
#                       Brutality Ivory Warmace                        2
#                       Chaos, Ender of the End                        1
#                       Conqueror Adamantite Mace                      1
#                       Crucifer                                       1
#                       Curved Axe                                     1
#                       Dawne                                          2
#                       Deadline, Voice Of Subtlety                    2
#                       Deathraze                                      1
#                       Deluge, Edge of the West                       2
#                       Demise                                         1
#                       Despair, Favor of Due Diligence                1
#                       Downfall, Scalpel Of The Emperor               1
#                       Dragon's Greatsword                            1
#                       Dreamsong                                      2
#                       Emberling, Defender of Delusions               1
#                       Extraction, Quickblade Of Trembling Hands      2
#                       Fate, Vengeance of Eternal Justice             1
#                       Feral Katana                                   2
#                       Fiery Glass Crusader                           2
#                       Final Critic                                   2
#                       Foul Edge                                      1
#                       Freak's Bite, Favor of Holy Might              1
#                       Ghastly Adamantite Protector                   1
# ...                                                                ...
# Male                  Verdict                                        5
#                       Victor Iron Spikes                             2
#                       Vindictive Glass Edge                          3
#                       War-Forged Gold Deflector                      4
#                       Warmonger, Gift of Suffering's End             3
#                       Warped Diamond Crusader                        2
#                       Warped Fetish                                  3
#                       Warped Iron Scimitar                           3
#                       Whistling Mithril Warblade                     1
#                       Winter's Bite                                  7
#                       Winterthorn, Defender of Shifting Worlds       2
#                       Woeful Adamantite Claymore                     2
#                       Wolf                                           7
#                       Wolf, Promise of the Moonwalker                5
#                       Worldbreaker                                   4
#                       Yearning Crusher                               3
#                       Yearning Mageblade                             4
# Other / Non-Disclosed Azurewrath                                     1
#                       Betrayal, Whisper of Grieving Widows           2
#                       Dreamsong                                      1
#                       Ghastly Adamantite Protector                   1
#                       Heartless Bone Dualblade                       1
#                       Hopeless Ebon Dualblade                        1
#                       Orbit                                          1
#                       Restored Bauble                                1
#                       Retribution Axe                                1
#                       Splitter, Foe Of Subtlety                      1
#                       Thunderfury Scimitar                           1
#                       Warped Fetish                                  1
#                       Warped Iron Scimitar                           2
#
# [281 rows x 1 columns]
